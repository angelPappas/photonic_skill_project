# %% [markdown]
# ## Post-processing: 3D length sweep

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("S_parameters_mmi2x2_with_bends_3D.csv").drop_duplicates()

# Extract unique axis values
lengths = np.sort(df["mmi_length (um)"].unique())

# Prepare empty grids
S31_grid = np.zeros(len(lengths))
S41_grid = np.zeros(len(lengths))

# Fill the grids
for _, row in df.iterrows():
    L = row["mmi_length (um)"]
    j = np.where(lengths == L)[0][0]

    S31_grid[j] = row["S31"]
    S41_grid[j] = row["S41"]

# Convert to dB
S31_dB = 20 * np.log10(np.abs(S31_grid))
S41_dB = 20 * np.log10(np.abs(S41_grid))

# %%
plt.plot(lengths, S31_dB, marker='o')
plt.plot(lengths, S41_dB, marker='o')
plt.xlabel("MMI Length (µm)")
plt.ylabel("S-parameter (dB)")
plt.title("S-parameters vs MMI Length for MMI 2x2 with Bends")
plt.legend(["S31", "S41"])
plt.grid()
plt.show()

# %%
import numpy as np

# condition where both S31_dB and S41_dB > -4
goal = -4.2
condition = (S31_dB > goal) & (S41_dB > goal)

# get indices where condition is True
indices = np.argwhere(condition)

# print the corresponding geometry values
for idx in indices.flatten():

    print(f"mmi_length = {lengths[idx]:.2f} µm, "
          f"S31_dB = {S31_dB[idx]:.2f}, S41_dB = {S41_dB[idx]:.2f}, loss = {-10*np.log10(S31_grid[idx]**2 + S41_grid[idx]**2):.2f} dB")
# Out:
# mmi_length = 3.20 µm, S31_dB = -3.92, S41_dB = -3.49, loss = inf dB
# mmi_length = 3.25 µm, S31_dB = -3.38, S41_dB = -3.52, loss = inf dB
# mmi_length = 3.30 µm, S31_dB = -3.13, S41_dB = -3.77, loss = inf dB
# mmi_length = 3.35 µm, S31_dB = -2.82, S41_dB = -4.00, loss = inf dB
# mmi_length = 3.40 µm, S31_dB = -2.66, S41_dB = -4.05, loss = inf dB
# mmi_length = 5.00 µm, S31_dB = -2.43, S41_dB = -4.14, loss = inf dB
# /tmp/ipykernel_1786/4208829253.py:14: RuntimeWarning: divide by zero encountered in log10
#   f"S31_dB = {S31_dB[idx]:.2f}, S41_dB = {S41_dB[idx]:.2f}, loss = {-10*np.log10(S31_grid[idx]**2 + S41_grid[idx]**2):.2f} dB")

# %% [markdown]
# I am choosing L = 3.15um as it is a compromise between loss and splitting

# %% [markdown]
# ## Post-processing for chosen MMI-region length

# %%
import re

df = pd.read_csv("S_parameters_mmi2x2_with_bends_3D_3p15.csv")

# Extract unique axis values
wavelengths = df["wavelength (um)"]

def parse_array(s):
    # remove outer brackets
    s = s.strip()[1:-1]
    # replace whitespace between numbers with commas
    s = re.sub(r"\s+", ",", s)
    return np.fromstring(s, sep=",")

# Convert all columns
wl  = parse_array(df["wavelength (um)"][0])
S11 = parse_array(df["S11"][0])
S21 = parse_array(df["S21"][0])
S31 = parse_array(df["S31"][0])
S41 = parse_array(df["S41"][0])

transmitance = S31**2 + S41**2
port3_ratio = S31**2 / transmitance
port4_ratio = S41**2 / transmitance

# Convert to dB
S11_dB = 20 * np.log10(np.abs(S11))
S21_dB = 20 * np.log10(np.abs(S21))
S31_dB = 20 * np.log10(np.abs(S31))
S41_dB = 20 * np.log10(np.abs(S41))

Loss_dB = -10 * np.log10(S31**2 + S41**2)

# %% [markdown]
# ### Scattering Parameters Spectrum

# %%
plt.plot(wl, S31_dB, label="S31", color='blue')
plt.plot(wl, S41_dB, label="S41", color='orange')
plt.xlabel("Wavelength (µm)")
plt.ylabel("S-parameter (dB)")
plt.title("S-parameters vs Wavelength for MMI 2x2 with Bends (L=3.15 µm)")
plt.legend()
plt.grid()

plt.show()

# %%
plt.plot(wl, S11_dB, label="S31", color='green')
plt.plot(wl, S21_dB, label="S41", color='red')
plt.plot(wl, S31_dB, label="S31", color='blue')
plt.plot(wl, S41_dB, label="S41", color='orange')
plt.xlabel("Wavelength (µm)")
plt.ylabel("S-parameter (dB)")
plt.title("S-parameters vs Wavelength for MMI 2x2 with Bends (L=3.15 µm)")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Loss Spectrum

# %%
plt.plot(wl, Loss_dB, label="Loss")
plt.xlabel("Wavelength (µm)")
plt.ylabel("Loss (dB)")
plt.title("Insertion Loss vs Wavelength for MMI 2x2 with Bends (L=3.15 µm)")
plt.legend()
plt.grid()
plt.show()

# %%
plt.plot(wl, port3_ratio, label="Port 3 Ratio")
plt.plot(wl, port4_ratio, label="Port 4 Ratio")
plt.xlabel("Wavelength (µm)")
plt.ylabel("Power Ratio")
plt.title("Splitting Ratios vs Wavelength for MMI 2x2 with Bends (L=3.15 µm)")
plt.legend()
plt.grid()
plt.show()

# %%
port3_ratio[int(len(wl)/2)], port4_ratio[int(len(wl)/2)], Loss_dB[int(len(wl)/2)]
# Out:
# (np.float64(0.5367357040143674),
#  np.float64(0.4632642959856325),
#  np.float64(0.4251798353918118))

# %% [markdown]
# **At 1550nm we have:**
# - **A 53.7/46.3 splitting ratio**
# - **Loss = 0.43 dB**

# %% [markdown]
# ## Visualize Device's cross-section

# %%
from mmi2x2 import mmi2x2_bend_waveguides
import meep as mp
import numpy as np
import matplotlib.pyplot as plt

wavelength = 1.55
fcen = 1/wavelength
df = 0.2*fcen
n_Si = 3.48  # silicon
n_SiO2 = 1.444  # SiO2

# %%
THREE_D = False
sim, cell, mode1, mode2, mode3, mode4, src_volume, resolution, pml_layers, geometry = mmi2x2_bend_waveguides(mmi_length=3.15)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# p1: {'center': Vector3<-6.575, 1.3, 0.0>, 'size': Vector3<0.0, 2.0, 20.0>, 'dims': 3, 'swigobj': min_corner:{-6.575000,0.300000,-10.000000}, max_corner:{-6.575000,2.300000,10.000000}}
# p2: {'center': Vector3<-6.575, -1.3, 0.0>, 'size': Vector3<0.0, 2.0, 20.0>, 'dims': 3, 'swigobj': min_corner:{-6.575000,-2.300000,-10.000000}, max_corner:{-6.575000,-0.300000,10.000000}}
# p3: {'center': Vector3<6.575, -1.3, 0.0>, 'size': Vector3<0.0, 2.0, 20.0>, 'dims': 3, 'swigobj': min_corner:{6.575000,-2.300000,-10.000000}, max_corner:{6.575000,-0.300000,10.000000}}
# p4: {'center': Vector3<6.575, 1.3, 0.0>, 'size': Vector3<0.0, 2.0, 20.0>, 'dims': 3, 'swigobj': min_corner:{6.575000,0.300000,-10.000000}, max_corner:{6.575000,2.300000,10.000000}}
# src: {'center': Vector3<-6.775, 1.3, 0.0>, 'size': Vector3<0.0, 2.0, 20.0>, 'dims': 3, 'swigobj': min_corner:{-6.775000,0.300000,-10.000000}, max_corner:{-6.775000,2.300000,10.000000}}
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00905045 s
# Working in 2D dimensions.
# Computational cell is 15.1667 x 6 x 0 with resolution 30
#      block, center = (0,0,0)
#           size (3.15,1,20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12.1104,12.1104,12.1104)
#      prism, center = (-3.575,0.8,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 160 vertices:
#           (-5.575,1.1,-10)
#           (-5.52437,1.0996,-10)
#           (-5.47373,1.09842,-10)
#           (-5.4231,1.09645,-10)
#           (-5.37247,1.09369,-10)
#           (-5.32184,1.09015,-10)
#           (-5.2712,1.08583,-10)
#           (-5.22057,1.08075,-10)
#           (-5.16994,1.07491,-10)
#           (-5.1193,1.06832,-10)
#           (-5.06867,1.06098,-10)
#           (-5.01804,1.05292,-10)
#           (-4.96741,1.04414,-10)
#           (-4.91677,1.03466,-10)
#           (-4.86614,1.02449,-10)
#           (-4.81551,1.01365,-10)
#           (-4.76487,1.00216,-10)
#           (-4.71424,0.990029,-10)
#           (-4.66361,0.977282,-10)
#           (-4.61297,0.963939,-10)
#           (-4.56234,0.950021,-10)
#           (-4.51171,0.935549,-10)
#           (-4.46108,0.920547,-10)
#           (-4.41044,0.905038,-10)
#           (-4.35981,0.889046,-10)
#           (-4.30918,0.872597,-10)
#           (-4.25854,0.855718,-10)
#           (-4.20791,0.838434,-10)
#           (-4.15728,0.820773,-10)
#           (-4.10665,0.802763,-10)
#           (-4.05601,0.784432,-10)
#           (-4.00538,0.76581,-10)
#           (-3.95475,0.746925,-10)
#           (-3.90411,0.727808,-10)
#           (-3.85348,0.708489,-10)
#           (-3.80285,0.688999,-10)
#           (-3.75222,0.669368,-10)
#           (-3.70158,0.649627,-10)
#           (-3.65095,0.629808,-10)
#           (-3.60032,0.609941,-10)
#           (-3.54968,0.590059,-10)
#           (-3.49905,0.570192,-10)
#           (-3.44842,0.550373,-10)
#           (-3.39778,0.530632,-10)
#           (-3.34715,0.511001,-10)
#           (-3.29652,0.491511,-10)
#           (-3.24589,0.472192,-10)
#           (-3.19525,0.453075,-10)
#           (-3.14462,0.43419,-10)
#           (-3.09399,0.415568,-10)
#           (-3.04335,0.397237,-10)
#           (-2.99272,0.379227,-10)
#           (-2.94209,0.361566,-10)
#           (-2.89146,0.344282,-10)
#           (-2.84082,0.327403,-10)
#           (-2.79019,0.310954,-10)
#           (-2.73956,0.294962,-10)
#           (-2.68892,0.279453,-10)
#           (-2.63829,0.264451,-10)
#           (-2.58766,0.249979,-10)
#           (-2.53703,0.236061,-10)
#           (-2.48639,0.222718,-10)
#           (-2.43576,0.209971,-10)
#           (-2.38513,0.197842,-10)
#           (-2.33449,0.186348,-10)
#           (-2.28386,0.175508,-10)
#           (-2.23323,0.16534,-10)
#           (-2.18259,0.155859,-10)
#           (-2.13196,0.14708,-10)
#           (-2.08133,0.139017,-10)
#           (-2.0307,0.131683,-10)
#           (-1.98006,0.12509,-10)
#           (-1.92943,0.119248,-10)
#           (-1.8788,0.114165,-10)
#           (-1.82816,0.109851,-10)
#           (-1.77753,0.106312,-10)
#           (-1.7269,0.103554,-10)
#           (-1.67627,0.101581,-10)
#           (-1.62563,0.100395,-10)
#           (-1.575,0.1,-10)
#           (-1.575,0.5,-10)
#           (-1.62563,0.500395,-10)
#           (-1.67627,0.501581,-10)
#           (-1.7269,0.503554,-10)
#           (-1.77753,0.506312,-10)
#           (-1.82816,0.509851,-10)
#           (-1.8788,0.514165,-10)
#           (-1.92943,0.519248,-10)
#           (-1.98006,0.52509,-10)
#           (-2.0307,0.531683,-10)
#           (-2.08133,0.539017,-10)
#           (-2.13196,0.54708,-10)
#           (-2.18259,0.555859,-10)
#           (-2.23323,0.56534,-10)
#           (-2.28386,0.575508,-10)
#           (-2.33449,0.586348,-10)
#           (-2.38513,0.597842,-10)
#           (-2.43576,0.609971,-10)
#           (-2.48639,0.622718,-10)
#           (-2.53703,0.636061,-10)
#           (-2.58766,0.649979,-10)
#           (-2.63829,0.664451,-10)
#           (-2.68892,0.679453,-10)
#           (-2.73956,0.694962,-10)
#           (-2.79019,0.710954,-10)
#           (-2.84082,0.727403,-10)
#           (-2.89146,0.744282,-10)
#           (-2.94209,0.761566,-10)
#           (-2.99272,0.779227,-10)
#           (-3.04335,0.797237,-10)
#           (-3.09399,0.815568,-10)
#           (-3.14462,0.83419,-10)
#           (-3.19525,0.853075,-10)
#           (-3.24589,0.872192,-10)
#           (-3.29652,0.891511,-10)
#           (-3.34715,0.911001,-10)
#           (-3.39778,0.930632,-10)
#           (-3.44842,0.950373,-10)
#           (-3.49905,0.970192,-10)
#           (-3.54968,0.990059,-10)
#           (-3.60032,1.00994,-10)
#           (-3.65095,1.02981,-10)
#           (-3.70158,1.04963,-10)
#           (-3.75222,1.06937,-10)
#           (-3.80285,1.089,-10)
#           (-3.85348,1.10849,-10)
#           (-3.90411,1.12781,-10)
#           (-3.95475,1.14693,-10)
#           (-4.00538,1.16581,-10)
#           (-4.05601,1.18443,-10)
#           (-4.10665,1.20276,-10)
#           (-4.15728,1.22077,-10)
#           (-4.20791,1.23843,-10)
#           (-4.25854,1.25572,-10)
#           (-4.30918,1.2726,-10)
#           (-4.35981,1.28905,-10)
#           (-4.41044,1.30504,-10)
#           (-4.46108,1.32055,-10)
#           (-4.51171,1.33555,-10)
#           (-4.56234,1.35002,-10)
#           (-4.61297,1.36394,-10)
#           (-4.66361,1.37728,-10)
#           (-4.71424,1.39003,-10)
#           (-4.76487,1.40216,-10)
#           (-4.81551,1.41365,-10)
#           (-4.86614,1.42449,-10)
#           (-4.91677,1.43466,-10)
#           (-4.96741,1.44414,-10)
#           (-5.01804,1.45292,-10)
#           (-5.06867,1.46098,-10)
#           (-5.1193,1.46832,-10)
#           (-5.16994,1.47491,-10)
#           (-5.22057,1.48075,-10)
#           (-5.2712,1.48583,-10)
#           (-5.32184,1.49015,-10)
#           (-5.37247,1.49369,-10)
#           (-5.4231,1.49645,-10)
#           (-5.47373,1.49842,-10)
#           (-5.52437,1.4996,-10)
#           (-5.575,1.5,-10)
#           dielectric constant epsilon diagonal = (12.1104,12.1104,12.1104)
#      prism, center = (-3.575,-0.8,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 160 vertices:
#           (-5.575,-1.5,-10)
#           (-5.52437,-1.4996,-10)
#           (-5.47373,-1.49842,-10)
#           (-5.4231,-1.49645,-10)
#           (-5.37247,-1.49369,-10)
#           (-5.32184,-1.49015,-10)
#           (-5.2712,-1.48583,-10)
#           (-5.22057,-1.48075,-10)
#           (-5.16994,-1.47491,-10)
#           (-5.1193,-1.46832,-10)
#           (-5.06867,-1.46098,-10)
#           (-5.01804,-1.45292,-10)
#           (-4.96741,-1.44414,-10)
#           (-4.91677,-1.43466,-10)
#           (-4.86614,-1.42449,-10)
#           (-4.81551,-1.41365,-10)
#           (-4.76487,-1.40216,-10)
#           (-4.71424,-1.39003,-10)
#           (-4.66361,-1.37728,-10)
#           (-4.61297,-1.36394,-10)
#           (-4.56234,-1.35002,-10)
#           (-4.51171,-1.33555,-10)
#           (-4.46108,-1.32055,-10)
#           (-4.41044,-1.30504,-10)
#           (-4.35981,-1.28905,-10)
#           (-4.30918,-1.2726,-10)
#           (-4.25854,-1.25572,-10)
#           (-4.20791,-1.23843,-10)
#           (-4.15728,-1.22077,-10)
#           (-4.10665,-1.20276,-10)
#           (-4.05601,-1.18443,-10)
#           (-4.00538,-1.16581,-10)
#           (-3.95475,-1.14693,-10)
#           (-3.90411,-1.12781,-10)
#           (-3.85348,-1.10849,-10)
#           (-3.80285,-1.089,-10)
#           (-3.75222,-1.06937,-10)
#           (-3.70158,-1.04963,-10)
#           (-3.65095,-1.02981,-10)
#           (-3.60032,-1.00994,-10)
#           (-3.54968,-0.990059,-10)
#           (-3.49905,-0.970192,-10)
#           (-3.44842,-0.950373,-10)
#           (-3.39778,-0.930632,-10)
#           (-3.34715,-0.911001,-10)
#           (-3.29652,-0.891511,-10)
#           (-3.24589,-0.872192,-10)
#           (-3.19525,-0.853075,-10)
#           (-3.14462,-0.83419,-10)
#           (-3.09399,-0.815568,-10)
#           (-3.04335,-0.797237,-10)
#           (-2.99272,-0.779227,-10)
#           (-2.94209,-0.761566,-10)
#           (-2.89146,-0.744282,-10)
#           (-2.84082,-0.727403,-10)
#           (-2.79019,-0.710954,-10)
#           (-2.73956,-0.694962,-10)
#           (-2.68892,-0.679453,-10)
#           (-2.63829,-0.664451,-10)
#           (-2.58766,-0.649979,-10)
#           (-2.53703,-0.636061,-10)
#           (-2.48639,-0.622718,-10)
#           (-2.43576,-0.609971,-10)
#           (-2.38513,-0.597842,-10)
#           (-2.33449,-0.586348,-10)
#           (-2.28386,-0.575508,-10)
#           (-2.23323,-0.56534,-10)
#           (-2.18259,-0.555859,-10)
#           (-2.13196,-0.54708,-10)
#           (-2.08133,-0.539017,-10)
#           (-2.0307,-0.531683,-10)
#           (-1.98006,-0.52509,-10)
#           (-1.92943,-0.519248,-10)
#           (-1.8788,-0.514165,-10)
#           (-1.82816,-0.509851,-10)
#           (-1.77753,-0.506312,-10)
#           (-1.7269,-0.503554,-10)
#           (-1.67627,-0.501581,-10)
#           (-1.62563,-0.500395,-10)
#           (-1.575,-0.5,-10)
#           (-1.575,-0.1,-10)
#           (-1.62563,-0.100395,-10)
#           (-1.67627,-0.101581,-10)
#           (-1.7269,-0.103554,-10)
#           (-1.77753,-0.106312,-10)
#           (-1.82816,-0.109851,-10)
#           (-1.8788,-0.114165,-10)
#           (-1.92943,-0.119248,-10)
#           (-1.98006,-0.12509,-10)
#           (-2.0307,-0.131683,-10)
#           (-2.08133,-0.139017,-10)
#           (-2.13196,-0.14708,-10)
#           (-2.18259,-0.155859,-10)
#           (-2.23323,-0.16534,-10)
#           (-2.28386,-0.175508,-10)
#           (-2.33449,-0.186348,-10)
#           (-2.38513,-0.197842,-10)
#           (-2.43576,-0.209971,-10)
#           (-2.48639,-0.222718,-10)
#           (-2.53703,-0.236061,-10)
#           (-2.58766,-0.249979,-10)
#           (-2.63829,-0.264451,-10)
#           (-2.68892,-0.279453,-10)
#           (-2.73956,-0.294962,-10)
#           (-2.79019,-0.310954,-10)
#           (-2.84082,-0.327403,-10)
#           (-2.89146,-0.344282,-10)
#           (-2.94209,-0.361566,-10)
#           (-2.99272,-0.379227,-10)
#           (-3.04335,-0.397237,-10)
#           (-3.09399,-0.415568,-10)
#           (-3.14462,-0.43419,-10)
#           (-3.19525,-0.453075,-10)
#           (-3.24589,-0.472192,-10)
#           (-3.29652,-0.491511,-10)
#           (-3.34715,-0.511001,-10)
#           (-3.39778,-0.530632,-10)
#           (-3.44842,-0.550373,-10)
#           (-3.49905,-0.570192,-10)
#           (-3.54968,-0.590059,-10)
#           (-3.60032,-0.609941,-10)
#           (-3.65095,-0.629808,-10)
#           (-3.70158,-0.649627,-10)
#           (-3.75222,-0.669368,-10)
#           (-3.80285,-0.688999,-10)
#           (-3.85348,-0.708489,-10)
#           (-3.90411,-0.727808,-10)
#           (-3.95475,-0.746925,-10)
#           (-4.00538,-0.76581,-10)
#           (-4.05601,-0.784432,-10)
#           (-4.10665,-0.802763,-10)
#           (-4.15728,-0.820773,-10)
#           (-4.20791,-0.838434,-10)
#           (-4.25854,-0.855718,-10)
#           (-4.30918,-0.872597,-10)
#           (-4.35981,-0.889046,-10)
#           (-4.41044,-0.905038,-10)
#           (-4.46108,-0.920547,-10)
#           (-4.51171,-0.935549,-10)
#           (-4.56234,-0.950021,-10)
#           (-4.61297,-0.963939,-10)
#           (-4.66361,-0.977282,-10)
#           (-4.71424,-0.990029,-10)
#           (-4.76487,-1.00216,-10)
#           (-4.81551,-1.01365,-10)
#           (-4.86614,-1.02449,-10)
#           (-4.91677,-1.03466,-10)
#           (-4.96741,-1.04414,-10)
#           (-5.01804,-1.05292,-10)
#           (-5.06867,-1.06098,-10)
#           (-5.1193,-1.06832,-10)
#           (-5.16994,-1.07491,-10)
#           (-5.22057,-1.08075,-10)
#           (-5.2712,-1.08583,-10)
#           (-5.32184,-1.09015,-10)
#           (-5.37247,-1.09369,-10)
#           (-5.4231,-1.09645,-10)
#           (-5.47373,-1.09842,-10)
#           (-5.52437,-1.0996,-10)
#           (-5.575,-1.1,-10)
#           dielectric constant epsilon diagonal = (12.1104,12.1104,12.1104)
#      prism, center = (3.575,-0.8,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 160 vertices:
#           (1.575,-0.5,-10)
#           (1.62563,-0.500395,-10)
#           (1.67627,-0.501581,-10)
#           (1.7269,-0.503554,-10)
#           (1.77753,-0.506312,-10)
#           (1.82816,-0.509851,-10)
#           (1.8788,-0.514165,-10)
#           (1.92943,-0.519248,-10)
#           (1.98006,-0.52509,-10)
#           (2.0307,-0.531683,-10)
#           (2.08133,-0.539017,-10)
#           (2.13196,-0.54708,-10)
#           (2.18259,-0.555859,-10)
#           (2.23323,-0.56534,-10)
#           (2.28386,-0.575508,-10)
#           (2.33449,-0.586348,-10)
#           (2.38513,-0.597842,-10)
#           (2.43576,-0.609971,-10)
#           (2.48639,-0.622718,-10)
#           (2.53703,-0.636061,-10)
#           (2.58766,-0.649979,-10)
#           (2.63829,-0.664451,-10)
#           (2.68892,-0.679453,-10)
#           (2.73956,-0.694962,-10)
#           (2.79019,-0.710954,-10)
#           (2.84082,-0.727403,-10)
#           (2.89146,-0.744282,-10)
#           (2.94209,-0.761566,-10)
#           (2.99272,-0.779227,-10)
#           (3.04335,-0.797237,-10)
#           (3.09399,-0.815568,-10)
#           (3.14462,-0.83419,-10)
#           (3.19525,-0.853075,-10)
#           (3.24589,-0.872192,-10)
#           (3.29652,-0.891511,-10)
#           (3.34715,-0.911001,-10)
#           (3.39778,-0.930632,-10)
#           (3.44842,-0.950373,-10)
#           (3.49905,-0.970192,-10)
#           (3.54968,-0.990059,-10)
#           (3.60032,-1.00994,-10)
#           (3.65095,-1.02981,-10)
#           (3.70158,-1.04963,-10)
#           (3.75222,-1.06937,-10)
#           (3.80285,-1.089,-10)
#           (3.85348,-1.10849,-10)
#           (3.90411,-1.12781,-10)
#           (3.95475,-1.14693,-10)
#           (4.00538,-1.16581,-10)
#           (4.05601,-1.18443,-10)
#           (4.10665,-1.20276,-10)
#           (4.15728,-1.22077,-10)
#           (4.20791,-1.23843,-10)
#           (4.25854,-1.25572,-10)
#           (4.30918,-1.2726,-10)
#           (4.35981,-1.28905,-10)
#           (4.41044,-1.30504,-10)
#           (4.46108,-1.32055,-10)
#           (4.51171,-1.33555,-10)
#           (4.56234,-1.35002,-10)
#           (4.61297,-1.36394,-10)
#           (4.66361,-1.37728,-10)
#           (4.71424,-1.39003,-10)
#           (4.76487,-1.40216,-10)
#           (4.81551,-1.41365,-10)
#           (4.86614,-1.42449,-10)
#           (4.91677,-1.43466,-10)
#           (4.96741,-1.44414,-10)
#           (5.01804,-1.45292,-10)
#           (5.06867,-1.46098,-10)
#           (5.1193,-1.46832,-10)
#           (5.16994,-1.47491,-10)
#           (5.22057,-1.48075,-10)
#           (5.2712,-1.48583,-10)
#           (5.32184,-1.49015,-10)
#           (5.37247,-1.49369,-10)
#           (5.4231,-1.49645,-10)
#           (5.47373,-1.49842,-10)
#           (5.52437,-1.4996,-10)
#           (5.575,-1.5,-10)
#           (5.575,-1.1,-10)
#           (5.52437,-1.0996,-10)
#           (5.47373,-1.09842,-10)
#           (5.4231,-1.09645,-10)
#           (5.37247,-1.09369,-10)
#           (5.32184,-1.09015,-10)
#           (5.2712,-1.08583,-10)
#           (5.22057,-1.08075,-10)
#           (5.16994,-1.07491,-10)
#           (5.1193,-1.06832,-10)
#           (5.06867,-1.06098,-10)
#           (5.01804,-1.05292,-10)
#           (4.96741,-1.04414,-10)
#           (4.91677,-1.03466,-10)
#           (4.86614,-1.02449,-10)
#           (4.81551,-1.01365,-10)
#           (4.76487,-1.00216,-10)
#           (4.71424,-0.990029,-10)
#           (4.66361,-0.977282,-10)
#           (4.61297,-0.963939,-10)
#           (4.56234,-0.950021,-10)
#           (4.51171,-0.935549,-10)
#           (4.46108,-0.920547,-10)
#           (4.41044,-0.905038,-10)
#           (4.35981,-0.889046,-10)
#           (4.30918,-0.872597,-10)
#           (4.25854,-0.855718,-10)
#           (4.20791,-0.838434,-10)
#           (4.15728,-0.820773,-10)
#           (4.10665,-0.802763,-10)
#           (4.05601,-0.784432,-10)
#           (4.00538,-0.76581,-10)
#           (3.95475,-0.746925,-10)
#           (3.90411,-0.727808,-10)
#           (3.85348,-0.708489,-10)
#           (3.80285,-0.688999,-10)
#           (3.75222,-0.669368,-10)
#           (3.70158,-0.649627,-10)
#           (3.65095,-0.629808,-10)
#           (3.60032,-0.609941,-10)
#           (3.54968,-0.590059,-10)
#           (3.49905,-0.570192,-10)
#           (3.44842,-0.550373,-10)
#           (3.39778,-0.530632,-10)
#           (3.34715,-0.511001,-10)
#           (3.29652,-0.491511,-10)
#           (3.24589,-0.472192,-10)
#           (3.19525,-0.453075,-10)
#           (3.14462,-0.43419,-10)
#           (3.09399,-0.415568,-10)
#           (3.04335,-0.397237,-10)
#           (2.99272,-0.379227,-10)
#           (2.94209,-0.361566,-10)
#           (2.89146,-0.344282,-10)
#           (2.84082,-0.327403,-10)
#           (2.79019,-0.310954,-10)
#           (2.73956,-0.294962,-10)
#           (2.68892,-0.279453,-10)
#           (2.63829,-0.264451,-10)
#           (2.58766,-0.249979,-10)
#           (2.53703,-0.236061,-10)
#           (2.48639,-0.222718,-10)
#           (2.43576,-0.209971,-10)
#           (2.38513,-0.197842,-10)
#           (2.33449,-0.186348,-10)
#           (2.28386,-0.175508,-10)
#           (2.23323,-0.16534,-10)
#           (2.18259,-0.155859,-10)
#           (2.13196,-0.14708,-10)
#           (2.08133,-0.139017,-10)
#           (2.0307,-0.131683,-10)
#           (1.98006,-0.12509,-10)
#           (1.92943,-0.119248,-10)
#           (1.8788,-0.114165,-10)
#           (1.82816,-0.109851,-10)
#           (1.77753,-0.106312,-10)
#           (1.7269,-0.103554,-10)
#           (1.67627,-0.101581,-10)
#           (1.62563,-0.100395,-10)
#           (1.575,-0.1,-10)
#           dielectric constant epsilon diagonal = (12.1104,12.1104,12.1104)
#      prism, center = (3.575,0.8,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 160 vertices:
#           (1.575,0.1,-10)
#           (1.62563,0.100395,-10)
#           (1.67627,0.101581,-10)
#           (1.7269,0.103554,-10)
#           (1.77753,0.106312,-10)
#           (1.82816,0.109851,-10)
#           (1.8788,0.114165,-10)
#           (1.92943,0.119248,-10)
#           (1.98006,0.12509,-10)
#           (2.0307,0.131683,-10)
#           (2.08133,0.139017,-10)
#           (2.13196,0.14708,-10)
#           (2.18259,0.155859,-10)
#           (2.23323,0.16534,-10)
#           (2.28386,0.175508,-10)
#           (2.33449,0.186348,-10)
#           (2.38513,0.197842,-10)
#           (2.43576,0.209971,-10)
#           (2.48639,0.222718,-10)
#           (2.53703,0.236061,-10)
#           (2.58766,0.249979,-10)
#           (2.63829,0.264451,-10)
#           (2.68892,0.279453,-10)
#           (2.73956,0.294962,-10)
#           (2.79019,0.310954,-10)
#           (2.84082,0.327403,-10)
#           (2.89146,0.344282,-10)
#           (2.94209,0.361566,-10)
#           (2.99272,0.379227,-10)
#           (3.04335,0.397237,-10)
#           (3.09399,0.415568,-10)
#           (3.14462,0.43419,-10)
#           (3.19525,0.453075,-10)
#           (3.24589,0.472192,-10)
#           (3.29652,0.491511,-10)
#           (3.34715,0.511001,-10)
#           (3.39778,0.530632,-10)
#           (3.44842,0.550373,-10)
#           (3.49905,0.570192,-10)
#           (3.54968,0.590059,-10)
#           (3.60032,0.609941,-10)
#           (3.65095,0.629808,-10)
#           (3.70158,0.649627,-10)
#           (3.75222,0.669368,-10)
#           (3.80285,0.688999,-10)
#           (3.85348,0.708489,-10)
#           (3.90411,0.727808,-10)
#           (3.95475,0.746925,-10)
#           (4.00538,0.76581,-10)
#           (4.05601,0.784432,-10)
#           (4.10665,0.802763,-10)
#           (4.15728,0.820773,-10)
#           (4.20791,0.838434,-10)
#           (4.25854,0.855718,-10)
#           (4.30918,0.872597,-10)
#           (4.35981,0.889046,-10)
#           (4.41044,0.905038,-10)
#           (4.46108,0.920547,-10)
#           (4.51171,0.935549,-10)
#           (4.56234,0.950021,-10)
#           (4.61297,0.963939,-10)
#           (4.66361,0.977282,-10)
#           (4.71424,0.990029,-10)
#           (4.76487,1.00216,-10)
#           (4.81551,1.01365,-10)
#           (4.86614,1.02449,-10)
#           (4.91677,1.03466,-10)
#           (4.96741,1.04414,-10)
#           (5.01804,1.05292,-10)
#           (5.06867,1.06098,-10)
#           (5.1193,1.06832,-10)
#           (5.16994,1.07491,-10)
#           (5.22057,1.08075,-10)
#           (5.2712,1.08583,-10)
#           (5.32184,1.09015,-10)
#           (5.37247,1.09369,-10)
#           (5.4231,1.09645,-10)
#           (5.47373,1.09842,-10)
#           (5.52437,1.0996,-10)
#           (5.575,1.1,-10)
#           (5.575,1.5,-10)
#           (5.52437,1.4996,-10)
#           (5.47373,1.49842,-10)
#           (5.4231,1.49645,-10)
#           (5.37247,1.49369,-10)
#           (5.32184,1.49015,-10)
#           (5.2712,1.48583,-10)
#           (5.22057,1.48075,-10)
#           (5.16994,1.47491,-10)
#           (5.1193,1.46832,-10)
#           (5.06867,1.46098,-10)
#           (5.01804,1.45292,-10)
#           (4.96741,1.44414,-10)
#           (4.91677,1.43466,-10)
#           (4.86614,1.42449,-10)
#           (4.81551,1.41365,-10)
#           (4.76487,1.40216,-10)
#           (4.71424,1.39003,-10)
#           (4.66361,1.37728,-10)
#           (4.61297,1.36394,-10)
#           (4.56234,1.35002,-10)
#           (4.51171,1.33555,-10)
#           (4.46108,1.32055,-10)
#           (4.41044,1.30504,-10)
#           (4.35981,1.28905,-10)
#           (4.30918,1.2726,-10)
#           (4.25854,1.25572,-10)
#           (4.20791,1.23843,-10)
#           (4.15728,1.22077,-10)
#           (4.10665,1.20276,-10)
#           (4.05601,1.18443,-10)
#           (4.00538,1.16581,-10)
#           (3.95475,1.14693,-10)
#           (3.90411,1.12781,-10)
#           (3.85348,1.10849,-10)
#           (3.80285,1.089,-10)
#           (3.75222,1.06937,-10)
#           (3.70158,1.04963,-10)
#           (3.65095,1.02981,-10)
#           (3.60032,1.00994,-10)
#           (3.54968,0.990059,-10)
#           (3.49905,0.970192,-10)
#           (3.44842,0.950373,-10)
#           (3.39778,0.930632,-10)
#           (3.34715,0.911001,-10)
#           (3.29652,0.891511,-10)
#           (3.24589,0.872192,-10)
#           (3.19525,0.853075,-10)
#           (3.14462,0.83419,-10)
#           (3.09399,0.815568,-10)
#           (3.04335,0.797237,-10)
#           (2.99272,0.779227,-10)
#           (2.94209,0.761566,-10)
#           (2.89146,0.744282,-10)
#           (2.84082,0.727403,-10)
#           (2.79019,0.710954,-10)
#           (2.73956,0.694962,-10)
#           (2.68892,0.679453,-10)
#           (2.63829,0.664451,-10)
#           (2.58766,0.649979,-10)
#           (2.53703,0.636061,-10)
#           (2.48639,0.622718,-10)
#           (2.43576,0.609971,-10)
#           (2.38513,0.597842,-10)
#           (2.33449,0.586348,-10)
#           (2.28386,0.575508,-10)
#           (2.23323,0.56534,-10)
#           (2.18259,0.555859,-10)
#           (2.13196,0.54708,-10)
#           (2.08133,0.539017,-10)
#           (2.0307,0.531683,-10)
#           (1.98006,0.52509,-10)
#           (1.92943,0.519248,-10)
#           (1.8788,0.514165,-10)
#           (1.82816,0.509851,-10)
#           (1.77753,0.506312,-10)
#           (1.7269,0.503554,-10)
#           (1.67627,0.501581,-10)
#           (1.62563,0.500395,-10)
#           (1.575,0.5,-10)
#           dielectric constant epsilon diagonal = (12.1104,12.1104,12.1104)
#      block, center = (-6.575,1.3,0)
#           size (2,0.4,20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12.1104,12.1104,12.1104)
#      block, center = (-6.575,-1.3,0)
#           size (2,0.4,20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12.1104,12.1104,12.1104)
#      block, center = (6.575,-1.3,0)
#           size (2,0.4,20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12.1104,12.1104,12.1104)
#      block, center = (6.575,1.3,0)
#           size (2,0.4,20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12.1104,12.1104,12.1104)
# subpixel-averaging is 36.256% done, 8.03363 s remaining
# subpixel-averaging is 91.7097% done, 0.364232 s remaining
# subpixel-averaging is 34.1232% done, 8.06165 s remaining
# subpixel-averaging is 81.0455% done, 0.949451 s remaining
# subpixel-averaging is 31.9904% done, 9.03699 s remaining
# subpixel-averaging is 81.0455% done, 0.99375 s remaining
# time for set_epsilon = 29.0888 s
# -----------
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# MPB solved for frequency_1(2.24516,0,0) = 0.700654 after 11 iters
# MPB solved for frequency_1(2.04472,0,0) = 0.645221 after 7 iters
# MPB solved for frequency_1(2.0445,0,0) = 0.645161 after 4 iters
# MPB solved for frequency_1(2.0445,0,0) = 0.645161 after 1 iters
# run 0 finished at t = 177.5 (10650 timesteps)

# %%
eps_data = sim.get_array(center=mp.Vector3(), size=cell.size, component=mp.Dielectric)
plt.figure()
plt.imshow(eps_data.transpose(), interpolation='spline36', cmap='binary')
plt.axis('off')
plt.show()
